# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # 데이터 처리

# %%
df = df.drop(['embark_town', 'who', 'adult_male', 'alive', 'class', 'embarked', 'alone', 'deck'], axis=1)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 48.9+ KB

# %%
df.fillna(df['age'].median(), inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female  28.0      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df = pd.get_dummies(df, dtype=int)

# %%
df
# Out:
#      survived  pclass   age  sibsp  parch     fare  sex_female  sex_male
# 0           0       3  22.0      1      0   7.2500           0         1
# 1           1       1  38.0      1      0  71.2833           1         0
# 2           1       3  26.0      0      0   7.9250           1         0
# 3           1       1  35.0      1      0  53.1000           1         0
# 4           0       3  35.0      0      0   8.0500           0         1
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 886         0       2  27.0      0      0  13.0000           0         1
# 887         1       1  19.0      0      0  30.0000           1         0
# 888         0       3  28.0      1      2  23.4500           1         0
# 889         1       1  26.0      0      0  30.0000           0         1
# 890         0       3  32.0      0      0   7.7500           0         1
#
# [891 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('survived', axis=1), df['survived'], test_size=0.4)

# %%
X_train
# Out:
#      pclass   age  sibsp  parch     fare  sex_female  sex_male
# 336       1  29.0      1      0  66.6000           0         1
# 207       3  26.0      0      0  18.7875           0         1
# 431       3  28.0      1      0  16.1000           1         0
# 464       3  28.0      0      0   8.0500           0         1
# 406       3  51.0      0      0   7.7500           0         1
# ..      ...   ...    ...    ...      ...         ...       ...
# 367       3  28.0      0      0   7.2292           1         0
# 837       3  28.0      0      0   8.0500           0         1
# 606       3  30.0      0      0   7.8958           0         1
# 389       2  17.0      0      0  12.0000           1         0
# 353       3  25.0      1      0  17.8000           0         1
#
# [534 rows x 7 columns]

# %%
X_test
# Out:
#      pclass   age  sibsp  parch     fare  sex_female  sex_male
# 28        3  28.0      0      0   7.8792           1         0
# 764       3  16.0      0      0   7.7750           0         1
# 578       3  28.0      1      0  14.4583           1         0
# 246       3  25.0      0      0   7.7750           1         0
# 746       3  16.0      1      1  20.2500           0         1
# ..      ...   ...    ...    ...      ...         ...       ...
# 494       3  21.0      0      0   8.0500           0         1
# 349       3  42.0      0      0   8.6625           0         1
# 879       1  56.0      0      1  83.1583           1         0
# 437       2  24.0      2      3  18.7500           1         0
# 121       3  28.0      0      0   8.0500           0         1
#
# [357 rows x 7 columns]

# %%
y_train
# Out:
# 336    0
# 207    1
# 431    1
# 464    0
# 406    0
#       ..
# 367    1
# 837    0
# 606    0
# 389    1
# 353    0
# Name: survived, Length: 534, dtype: int64

# %%
y_test
# Out:
# 28     1
# 764    0
# 578    0
# 246    0
# 746    0
#       ..
# 494    0
# 349    0
# 879    1
# 437    1
# 121    0
# Name: survived, Length: 357, dtype: int64

# %% [markdown]
# # 모델 학습

# %%
mlp = MLPClassifier(max_iter=300, solver='adam', verbose=1)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 4.00774806
# Iteration 2, loss = 3.06096867
# Iteration 3, loss = 2.16874446
# Iteration 4, loss = 1.32469920
# Iteration 5, loss = 0.82202033
# Iteration 6, loss = 0.74268561
# Iteration 7, loss = 0.89288153
# Iteration 8, loss = 0.96319047
# Iteration 9, loss = 0.87413266
# Iteration 10, loss = 0.74964176
# Iteration 11, loss = 0.66923390
# Iteration 12, loss = 0.66274463
# Iteration 13, loss = 0.68161673
# Iteration 14, loss = 0.67624781
# Iteration 15, loss = 0.64298406
# Iteration 16, loss = 0.60871967
# Iteration 17, loss = 0.58893676
# Iteration 18, loss = 0.59536892
# Iteration 19, loss = 0.58937887
# Iteration 20, loss = 0.57292896
# Iteration 21, loss = 0.56619324
# Iteration 22, loss = 0.56415236
# Iteration 23, loss = 0.55781088
# Iteration 24, loss = 0.55156379
# Iteration 25, loss = 0.54698678
# Iteration 26, loss = 0.54402041
# Iteration 27, loss = 0.53942589
# Iteration 28, loss = 0.53642710
# Iteration 29, loss = 0.53437337
# Iteration 30, loss = 0.53310309
# Iteration 31, loss = 0.52893499
# Iteration 32, loss = 0.52647849
# Iteration 33, loss = 0.52515095
# Iteration 34, loss = 0.52298470
# Iteration 35, loss = 0.52009410
# Iteration 36, loss = 0.51766156
# Iteration 37, loss = 0.51607303
# Iteration 38, loss = 0.51425804
# Iteration 39, loss = 0.51144753
# Iteration 40, loss = 0.51034949
# Iteration 41, loss = 0.50853651
# Iteration 42, loss = 0.50602232
# Iteration 43, loss = 0.50495868
# Iteration 44, loss = 0.50370867
# Iteration 45, loss = 0.50089029
# Iteration 46, loss = 0.49910748
# Iteration 47, loss = 0.49751757
# Iteration 48, loss = 0.49589365
# Iteration 49, loss = 0.49417408
# Iteration 50, loss = 0.49233662
# Iteration 51, loss = 0.49113222
# Iteration 52, loss = 0.48955382
# Iteration 53, loss = 0.48844306
# Iteration 54, loss = 0.48710787
# Iteration 55, loss = 0.48561081
# Iteration 56, loss = 0.48460691
# Iteration 57, loss = 0.48367990
# Iteration 58, loss = 0.48239833
# Iteration 59, loss = 0.48068280
# Iteration 60, loss = 0.47949877
# Iteration 61, loss = 0.47836717
# Iteration 62, loss = 0.47680562
# Iteration 63, loss = 0.47587257
# Iteration 64, loss = 0.47564759
# Iteration 65, loss = 0.47449285
# Iteration 66, loss = 0.47251645
# Iteration 67, loss = 0.47200294
# Iteration 68, loss = 0.47224250
# Iteration 69, loss = 0.46984121
# Iteration 70, loss = 0.47012677
# Iteration 71, loss = 0.46889782
# Iteration 72, loss = 0.46679272
# Iteration 73, loss = 0.46680056
# Iteration 74, loss = 0.46608977
# Iteration 75, loss = 0.46456371
# Iteration 76, loss = 0.46457022
# Iteration 77, loss = 0.46307636
# Iteration 78, loss = 0.46193705
# Iteration 257, loss = 0.40453536
# Iteration 258, loss = 0.40489237
# Iteration 259, loss = 0.40496842
# Iteration 260, loss = 0.40601177
# Iteration 261, loss = 0.40422816
# Iteration 262, loss = 0.40381873
# Iteration 263, loss = 0.40456346
# Iteration 264, loss = 0.40896207
# Iteration 265, loss = 0.40385952
# Iteration 266, loss = 0.40868490
# Iteration 267, loss = 0.40471652
# Iteration 268, loss = 0.40585244
# Iteration 269, loss = 0.40238355
# Iteration 270, loss = 0.40395501
# Iteration 271, loss = 0.40298461
# Iteration 272, loss = 0.40337986
# Iteration 273, loss = 0.40346145
# Iteration 274, loss = 0.40287659
# Iteration 275, loss = 0.40110199
# Iteration 276, loss = 0.40204170
# Iteration 277, loss = 0.40140969
# Iteration 278, loss = 0.40144216
# Iteration 279, loss = 0.40250207
# Iteration 280, loss = 0.40126353
# Iteration 281, loss = 0.40374993
# Iteration 282, loss = 0.40184235
# Iteration 283, loss = 0.40069866
# Iteration 284, loss = 0.39997721
# Iteration 285, loss = 0.40091357
# Iteration 286, loss = 0.40063889
# Iteration 287, loss = 0.40041407
# Iteration 288, loss = 0.40163051
# Iteration 289, loss = 0.40002170
# Iteration 290, loss = 0.40234823
# Iteration 291, loss = 0.40114016
# Iteration 292, loss = 0.40206733
# Iteration 293, loss = 0.40493984
# Iteration 294, loss = 0.40128760
# Iteration 295, loss = 0.40230105
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(max_iter=300, verbose=1)

# %%
y_pred = mlp.predict(X_test)

# %% [markdown]
# ## 정확률

# %%
incorrect = 0
for i in range(len(y_pred)):
    if y_pred[i] != y_test.iloc[i]:
        incorrect += 1

# %%
accuracy = ((len(y_test) - incorrect)/len(y_test)) * 100

# %% [markdown]
# ##1

# %%
tp1 = 0
fn1 = 0
fp1 = 0

for i in range(len(y_pred)):
  if y_pred[i] == y_test.iloc[i]:
    if y_pred[i] == 1:
      tp1 += 1

  else:
    if y_pred[i] == 1:
      fp1 += 1
    else:
      fn1 += 1

precision = tp1/(tp1+fp1)
recall = tp1/(tp1+fn1)
f1_score = (2*precision*recall)/(precision+recall)

print(f"Accuracy: {accuracy}%")
print(f"Precision: {precision * 100}%")
print(f"Recall: {recall * 100}%")
print(f"F1 Score: {f1_score * 100}%")
# Out:
# Accuracy: 79.83193277310924%
# Precision: 67.88321167883211%
# Recall: 76.85950413223141%
# F1 Score: 72.09302325581396%

# %% [markdown]
# ##0

# %%
tp0 = 0
fn0 = 0
fp0 = 0

for i in range(len(y_pred)):
  if y_pred[i] == y_test.iloc[i]:
    if y_pred[i] == 0:
      tp0 += 1

  else:
    if y_pred[i] == 0:
      fp0 += 1
    else:
      fn0 += 1

precision = tp0/(tp0+fp0)
recall = tp0/(tp0+fn0)
f1_score = (2*precision*recall)/(precision+recall)

print(f"Accuracy: {accuracy}%")
print(f"Precision: {precision * 100}%")
print(f"Recall: {recall * 100}%")
print(f"F1 Score: {f1_score * 100}%")
# Out:
# Accuracy: 79.83193277310924%
# Precision: 87.27272727272727%
# Recall: 81.35593220338984%
# F1 Score: 84.21052631578948%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       236
#            1       0.68      0.77      0.72       121
#
#     accuracy                           0.80       357
#    macro avg       0.78      0.79      0.78       357
# weighted avg       0.81      0.80      0.80       357
